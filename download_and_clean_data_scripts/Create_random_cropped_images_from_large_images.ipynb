# %%
from PIL import Image
from random import randint
import uuid
from multiprocessing import Pool
import os

# %%
img_dir = r"./all_images/"
k = 0

def crop_images(path_and_file):
    try:
        with Image.open(path_and_file[0]) as im:
            x, y = im.size
            crop_quantity = int((x*y) / (224*224))

            for i in range(crop_quantity):
                first_x = randint(0, (x-230))
                first_y = randint(0, (y-230))
                second_x = randint(first_x + 224, x)
                second_y = randint(first_y + 224, y)
                box = (first_x, first_y, second_x, second_y)
                cropped_image = im.crop(box)
                cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
    except IOError:
        os.rename(path_and_file[0], '/home/ubuntu/storage/error_files/' + path_and_file[1])

if __name__ == "__main__":
    img_dir = r"./all_images/"
    images = []

    for filename in os.listdir(img_dir):
        filepath = os.path.join(img_dir, filename)
        images.append([filepath, filename])

    pool = Pool(processes=16) 
    pool.map(crop_images, images)

    print("Done!")
# Out:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-18:
# Traceback (most recent call last):
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-26:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-29:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
# Process ForkPoolWorker-31:
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-33766a2e76a6> in <module>()
#      28
#      29     pool = Pool(processes=16)
# ---> 30     pool.map(crop_images, images)
#      31
#      32     print("Done!")
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-28:
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
# Process ForkPoolWorker-21:
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
# KeyboardInterrupt
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
# Process ForkPoolWorker-24:
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
# KeyboardInterrupt
# Process ForkPoolWorker-19:
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-23:
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
# Process ForkPoolWorker-20:
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-25:
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
# KeyboardInterrupt
# Process ForkPoolWorker-22:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
# KeyboardInterrupt
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-30:
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "<ipython-input-9-33766a2e76a6>", line 17, in crop_images
#     cropped_image.save('/home/ubuntu/storage/cropped_images/' + str(uuid.uuid4()) + '.jpg')
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
# KeyboardInterrupt
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
# KeyboardInterrupt
